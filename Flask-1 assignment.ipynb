# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %%
#Flask is a lightweight web framework for Python. It provides a simple yet powerful set of tools and libraries to build web applications.

# %%
#Flask is popular for its simplicity, flexibility, and ease of use. It allows developers to build web applications quickly and efficiently, while still providing the necessary tools and extensions to handle common web development tasks.

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello, World!</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![flask attachment.PNG](attachment:01cd720d-c887-44ae-b73c-3b4668e28d5b.PNG)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %%
#App routing in Flask refers to the process of defining URL routes for handling different HTTP requests in a Flask application. Routes define the URL patterns and the corresponding view functions that will be executed when those URLs are accessed.

# %%
#In Flask, we use the @app.route() decorator to define routes. The decorator is applied to a view function, specifying the URL route as its argument. The view function is then responsible for generating the response for that particular route.

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details: Company Name: ABC Corporation Location: India Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/welecome')
def welecome():
    return 'Welecome to ABC corporation'

@app.route('/')
def company_details():
    return '''Company Name: ABC corporation
    Location : India
    contact Details: 999-999-999'''

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![flask3.PNG](attachment:d35db2b2-5499-4076-9361-b6926d607cfd.PNG)![download.png](attachment:f3495c01-2e82-4ff6-a8bc-d8b47755915d.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %%
#The url_for() function in Flask is used for URL building. It generates a URL for a given endpoint, taking into account the routing rules defined in your Flask application.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def home():
    return 'Welcome to the homepage!'

@app.route('/user/<username>')
def user_profile(username):
    return f'Welcome, {username}!'

if __name__ == '__main__':
    with app.test_request_context():
        home_url = url_for('home')
        user_profile_url = url_for('user_profile', username='John')

        print('Home URL:', home_url)
        print('User Profile URL:', user_profile_url)

# %% [markdown]
# ![flask4.PNG](attachment:2301eeed-2c73-4ec6-a97c-2121965e2d1a.PNG)
